# %% [markdown]
# # Artifacts Analysis Notebook
#
# This notebook loads and analyzes the Artifacts.csv data from SOP parsing.

# %%
# Import Required Libraries
import pandas as pd

# %%
# Load CSV File into DataFrame
df_artifacts = pd.read_csv('../runs/Artifacts.csv')
df_artifacts.head()
# Out:
#              Artifact                                                SOP  \
# 0  Övergripande behov  docs\SOP\1.Kravställning\01_vision_och_malbild.md
# 1    Vision & målbild  docs\SOP\1.Kravställning\01_vision_och_malbild.md
# 2    Vision & målbild  docs\SOP\1.Kravställning\01_vision_och_malbild.md
# 3    Vision & målbild  docs\SOP\1.Kravställning\01_vision_och_malbild.md
# 4    Vision & målbild  docs\SOP\1.Kravställning\01_vision_och_malbild.md
#
#   Input or output       Responsible
# 0           input               NaN
# 1           input               NaN
# 2           input               NaN
# 3          output  Business Analyst
# 4          output  Business Analyst

# %%
df_artifacts = df_artifacts["Artifact"].drop_duplicates().sort_values()
df_artifacts.to_csv('../runs/Artifacts_simple.csv', index=False)
