# %% [markdown]
# # Artifacts Analysis Notebook
#
# This notebook loads and analyzes the Artifacts.csv data from SOP parsing.

# %%
# Import Required Libraries
import pandas as pd

# %%
# Load CSV File into DataFrame
df_artifacts = pd.read_csv('../runs/Artifacts.csv')
df_artifacts.head()
# Out:
#                       Artifact  \
# 0           Problembeskrivning
# 1  Övergripande verksamhetsmål
# 2  Eventuella strategidokument
# 3                Produktvision
# 4        Målbild för produkten
#
#                                                  SOP Input or output
# 0  docs\SOP\1.Kravställning\01_vision_och_malbild.md           input
# 1  docs\SOP\1.Kravställning\01_vision_och_malbild.md           input
# 2  docs\SOP\1.Kravställning\01_vision_och_malbild.md           input
# 3  docs\SOP\1.Kravställning\01_vision_och_malbild.md          output
# 4  docs\SOP\1.Kravställning\01_vision_och_malbild.md          output

# %%
df_artifacts = df_artifacts["Artifact"].drop_duplicates().sort_values()
df_artifacts.to_csv('../runs/Artifacts_simple.csv', index=False)
