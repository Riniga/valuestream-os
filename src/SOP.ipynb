# %% [markdown]
# # SOP Analysis Notebook
#
# This notebook loads and analyzes the SOP.csv data from SOP parsing.

# %%
# Import Required Libraries
import pandas as pd

# %%
# Load CSV File into DataFrame
df_sop = pd.read_csv('../runs/SOP.csv')
df_sop.head()
# Out:
#                                                  SOP             Delprocess  \
# 0  docs\SOP\1.Kravställning\01_vision_och_malbild.md       Vision & målbild
# 1  docs\SOP\1.Kravställning\02_affarsmal_och_vard...  Affärsmål & värdebild
# 2  docs\SOP\1.Kravställning\03_scope_och_avgransn...  Scope & avgränsningar
# 3    docs\SOP\1.Kravställning\04_stakeholderkarta.md      Stakeholder-karta
# 4         docs\SOP\1.Kravställning\05_domananalys.md            Domänanalys
#
#      processsteg
# 0  Kravställning
# 1  Kravställning
# 2  Kravställning
# 3  Kravställning
# 4  Kravställning

# %%
df_sop[df_sop["processsteg"] == "Kravställning"]
# Out:
#                                                  SOP  \
# 0  docs\SOP\1.Kravställning\01_vision_och_malbild.md
# 1  docs\SOP\1.Kravställning\02_affarsmal_och_vard...
# 2  docs\SOP\1.Kravställning\03_scope_och_avgransn...
# 3    docs\SOP\1.Kravställning\04_stakeholderkarta.md
# 4         docs\SOP\1.Kravställning\05_domananalys.md
# 5       docs\SOP\1.Kravställning\06_user_journeys.md
# 6     docs\SOP\1.Kravställning\07_skapa_story_map.md
# 7  docs\SOP\1.Kravställning\08_gruppera_i_epics_o...
# 8  docs\SOP\1.Kravställning\09_prioritera_backlog.md
# 9  docs\SOP\1.Kravställning\10_definiera_framgang...
#
#                            Delprocess    processsteg
# 0                    Vision & målbild  Kravställning
# 1               Affärsmål & värdebild  Kravställning
# 2               Scope & avgränsningar  Kravställning
# 3                   Stakeholder-karta  Kravställning
# 4                         Domänanalys  Kravställning
# 5         User Journeys / huvudflöden  Kravställning
# ...
