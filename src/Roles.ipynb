# %%
import pandas as pd

# %%
df_roles = pd.read_csv('../runs/Roles.csv')
df_roles[df_roles["Role"] == "Dataarkitekt"]
# Out:
#             Role                                                SOP  \
# 67  Dataarkitekt  docs\SOP\2. Målarkitektur\06_Definiera datamod...
# 93  Dataarkitekt  docs\SOP\2. Målarkitektur\11_ Dokumentera måla...
#
#    Type of RACI
# 67            R
# 93            C

# %%
df_roles = df_roles["Role"].drop_duplicates().sort_values()
df_roles
# Out:
# 25     Användarrepresentanter
# 0            Business Analyst
# 67               Dataarkitekt
# 74                     DevOps
# 45        Enterprise Arkitekt
# 21           Lösningsarkitekt
# 1                Produktägare
# 3               Projektledare
# 128              Scrum Master
# 47               Teknisk Lead
# 140                   Testare
# 22                         UX
# 11                 Utvecklare
# 2         Verksamhetsexperter
# Name: Role, dtype: str
